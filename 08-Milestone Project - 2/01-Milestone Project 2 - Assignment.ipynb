# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Milestone Project 2 - Blackjack Game
# In this milestone project you will be creating a Complete BlackJack Card Game in Python.
#
# Here are the requirements:
#
# * You need to create a simple text-based [BlackJack](https://en.wikipedia.org/wiki/Blackjack) game
# * The game needs to have one player versus an automated dealer.
# * The player can stand or hit.
# * The player must be able to pick their betting amount.
# * You need to keep track of the player's total money.
# * You need to alert the player of wins, losses, or busts, etc...
#
# And most importantly:
#
# * **You must use OOP and classes in some portion of your game. You can not just use functions in your game. Use classes to help you define the Deck and the Player's hand. There are many right ways to do this, so explore it well!**
#
#
# Feel free to expand this game. Try including multiple players. Try adding in Double-Down and card splits! Remember to you are free to use any resources you want and as always:
#
# # HAVE FUN!

# %%
import random 
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
            'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}

class Card:
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
        
    def __str__(self):
        return self.rank + ' of ' + self.suit
    
    def score(self):
        return self.value 

class Deck:
    def __init__(self):
        # Note this only happens once upon creation of a new Deck
        self.all_cards = [] # superseeeded by hand
        for suit in suits:
            for rank in ranks:
                # This assumes the Card class has already been defined!
                self.all_cards.append(Card(suit,rank))
                
    def shuffle(self):
        # Note this doesn't return anything
        random.shuffle(self.all_cards)
        
    def deal_one(self):
        # Note we remove one card from the list of all_cards
        return self.all_cards.pop()      
    
class Player:
    def __init__(self,name,money):
        self.name = name
        self.money = money
        #A new player has no cards
        self.all_cards = [] 
        
    def remove_one(self):
        # Note we remove one card from the list of all_cards
        # We state 0 to remove from the "top" of the deck
        # We'll imagine index -1 as the bottom of the deck
        return self.all_cards.pop(0)
    
    def add_cards(self,new_cards):
        if type(new_cards) == type([]):
            self.all_cards.extend(new_cards)
        else:
            self.all_cards.append(new_cards)
    
    def __str__(self):
        return f'Player {self.name} has {len(self.all_cards)} cards.'
    
    def deposit(self,amount):
        self.money = self.money + amount 

    def withdraw(self,amount): 
        if (self.money - amount > 0 ):
            self.money = self.money - self.amount
    
    def balance(self ):
        balance = self.money
        return balance
    
    def score(self): 
        for item in self.all_cards: 
            total += self.all_cards[item].value
        return total 

player_one      = Player("One",100)
dealer          = Player("Dealer",100)
player_one_hand = []
dealer_hand     = []
new_deck        = Deck()
new_deck.shuffle()
# player_hand = []
# dealer_hand = []

# deal two cards to the dealer and the first player
# player_one_hand.append(player_one.remove_one())
# print(player_one_hand[0].value)
# print(dealer.money)
# player_one.deposit(100)
# print(player_one.money)
import pdb
game_on = True
round_num = 0
# while game_on:
# deal two cards to the dealer and the first player
for x in range(2):
    player_one.add_cards(new_deck.deal_one())
    dealer.add_cards(new_deck.deal_one())
# add cards to the hand list
# dealer_hand.append(dealer.remove_one)
# player_one_hand.append(player_one.remove_one)

print ('Dealer has') 
print (dealer.all_cards[0])
print ('With a value of ')
print (dealer.all_cards[0].value)
print ('Player has') 
# print (str(player_one.all_cards[0] ) +' and ' + str(player_one.all_cards[1]))
print (player_one.all_cards[0]) 
print (player_one.all_cards[1])
# print ('With a value of '+  player_one.score )
# print (player_one.all_cards[0].value)
print ('Would you like to hit, stand , double or split ? or for help with what these mean type --help')
# Out:
# Dealer has
# Six of Clubs
# With a value of
# 6
# Player has
# Two of Hearts
# Ten of Spades
# Would you like to hit, stand , double or split ? or for help with what these mean type --help

# %%
class Dog:
    
    # Class Object Attribute
    species = 'mammal'
    
    def __init__(self,breed,name,value):
        self.breed = breed
        self.name = name
        self.value = value 
        
        
sam = Dog ('Lab','Sam',100) 
print(sam.name)
print(sam.value)
# Out:
# Sam
# 100
